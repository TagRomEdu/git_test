# %% [markdown]
# ## 🧠 Шпаргалка по Git и GitHub
#
# ### 📌 Настройка Git (один раз)
#
# ```bash
# git config --global user.name "Ваше Имя"
# git config --global user.email "email@example.com"
# ```
#
# ---
#
# ### 📁 Работа с репозиторием
#
# #### 1. Инициализация нового репозитория
#
# ```bash
# git init
# ```
#
# Создает `.git` — папку с историей версий.
#
# ---
#
# #### 2. Проверка статуса
#
# ```bash
# git status
# ```
#
# Показывает, что изменено и не сохранено в истории.
#
# ---
#
# #### 3. Добавление файлов в индекс
#
# ```bash
# git add filename       # добавить один файл
# git add .              # добавить всё
# ```
#
# ---
#
# #### 4. Сохранение изменений (коммит)
#
# ```bash
# git commit -m "Комментарий к изменениям"
# ```
#
# ---
#
# #### 5. Просмотр истории коммитов
#
# ```bash
# git log
# ```
#
# ---
#
# #### 6. Сравнение изменений
#
# ```bash
# git diff              # разница между рабочими файлами и индексом
# ```
#
# ---
#
# ### 🌐 Работа с GitHub
#
# #### 1. Подключение удалённого репозитория
#
# ```bash
# git remote add origin https://github.com/ваш-логин/имя-репо.git
# ```
#
# #### 2. Отправка изменений на GitHub
#
# ```bash
# git branch -M main             # переименовать ветку в main (если нужно)
# git push -u origin main        # первый пуш
# git push                       # следующий пуш
# ```
#
# #### 3. Получение изменений с GitHub
#
# ```bash
# git pull origin main
# ```
#
# ---
#
# ### 🌿 Работа с ветками
#
# ```bash
# git branch                    # список веток
# git checkout -b new-branch    # создать и перейти в новую ветку
# git checkout main             # вернуться в main
# git merge new-branch          # слить изменения из ветки
# ```
#
# ---
#
# ### 🧹 Отмена изменений
#
# ```bash
# git restore filename          # откатить файл
# git reset --soft HEAD~1       # отменить последний коммит, оставить изменения
# git reset --hard HEAD~1       # удалить коммит и изменения (осторожно!)
# ```
#
# ---
#
# ### 💡 Полезные команды
#
# ```bash
# git clone <url>               # клонировать репозиторий
# git stash                     # временно убрать изменения
# git stash pop                 # вернуть их обратно
# ```
#
# ---
#
# ## 📎 Советы
#
# * Коммиты делай чаще, с понятными сообщениями.
# * Не бойся испортить — Git можно откатить.
# * Практикуйся на тестовых репозиториях.
